# %%
# 라이브러리 불러오기
import seaborn as sns

# titanic 데이터셋 가져오기
df = sns.load_dataset('titanic')

# age 열의 첫 10개 데이터 출력 (5 행에 NaN 값)
df['age'].head(10)
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5     NaN
# 6    54.0
# 7     2.0
# 8    27.0
# 9    14.0
# Name: age, dtype: float64

# %%
# 나이에 대한 histogram 그리기
df['age'].hist()
# Out:
# <Axes: >

# %%
# 결측치 평균으로 대처하기
# age 열의 NaN값을 다른 나이 데이터의 평균으로 변경하기
mean_age = df['age'].mean(axis=0)   # age 열의 평균 계산 (NaN 값 제외)
df['age'] = df['age'].fillna(mean_age)

# age 열의 첫 10개 데이터 출력 (5 행에 NaN 값이 평균으로 대체)
df['age'].head(10)
# Out:
# 0    22.000000
# 1    38.000000
# 2    26.000000
# 3    35.000000
# 4    35.000000
# 5    29.699118
# 6    54.000000
# 7     2.000000
# 8    27.000000
# 9    14.000000
# Name: age, dtype: float64

# %%
df = sns.load_dataset('titanic')
# 객실별 성별에 따른 평균값으로 해당 결측치를 대처
df['age'] = df.groupby(['pclass','sex'])['age'].transform('mean')
# 이게 강력한 결측치 처리 방식임

# %%
# 평균과 vs 중위수 
# 과연 어떤 기준으로 선택을 하면 좋을까?
# 평균
    # 이상치의 비중이 낮을 때
# 중위수
    # 이상치의 비중이 높을 때
# 이상치
    # 데이터의 어떤 패턴을 넘어서는 갑자기 확 크거나 작은 애들
# 결측치가 많을 때 (결측치가 50% 이상일 때)
    # 머신러닝이나 딥러닝 기반의 보간을 고려해보는 것이 좋다
