# %%
# 라이브러리 불러오기
import pandas as pd

# %%
pwd
# Out:
# 'c:\\Users\\sally\\SKNPYWORKSPACE\\pandas-data-analysis\\part2'

# %%
# 경로 폴더의 모든 파일 목록 확인하기
import os
os.listdir("./data")
# Out:
# ['df_excelwriter.xlsx',
#  'df_sample.csv',
#  'df_sample.json',
#  'df_sample.xlsx',
#  'df_sample_columns.json',
#  'df_sample_index.json',
#  'df_sample_no_index.csv',
#  'df_sample_no_index.xlsx',
#  'df_sample_records.json',
#  'df_sample_split.json',
#  'df_sample_values.json',
#  'read_csv_sample.csv',
#  'read_json_sample.json',
#  'sample.html',
#  'test.csv',
#  'test.json',
#  '남북한발전전력량.xlsx']

# %%
#현재 폴더의 모든 파일 목록 (데이터) 확인하기
from glob import glob
#glob("./data/*.*")  

#현재 폴더의 모든 파일 목록 확인하기 + 하위폴더 경로 모두 검색
#recursive=True는 파일명까지 나오게
#glob('**/*', recursive=True)

# df로 시작하는 모든 파일 확인하기
#glob("./data/df*.*")

#파일명만 리스트로 담으려면
[files.split('\\')[-1] for files in glob('./data/*.*')]
# Out:
# ['df_excelwriter.xlsx',
#  'df_sample.csv',
#  'df_sample.json',
#  'df_sample.xlsx',
#  'df_sample_columns.json',
#  'df_sample_index.json',
#  'df_sample_no_index.csv',
#  'df_sample_no_index.xlsx',
#  'df_sample_records.json',
#  'df_sample_split.json',
#  'df_sample_values.json',
#  'read_csv_sample.csv',
#  'read_json_sample.json',
#  'sample.html',
#  'test.csv',
#  'test.json',
#  '남북한발전전력량.xlsx']

# %%
# 파일경로를 찾고, 변수 file_path에 저장 (문자열 결합)
file_path = './data/read_csv_sample.csv'

print(file_path)
# Out:
# ./data/read_csv_sample.csv

# %%
# 샘플.csv 파일 읽어오기
from glob import glob
glob("./data/*.csv")[0]
# Out:
# './data\\df_sample.csv'

# %%
# 샘플.csv 파일 읽어오기
pd.read_csv(glob("./data/*.csv")[0])
# Out:
#     name algol basic c++
# 0  Jerry     A     C  B+
# 1   Riah    A+     B   C
# 2   Paul     B    B+  C+

# %%
# 파일경로를 찾고, 변수 file_path에 저장 (os 모듈 활용)
# os 모듈의 역할은 운영체제에 맞게 경로를 설정
# 다양한 환경에서 쓰기 위함
file_path2 = os.path.join('data', 'read_csv_sample.csv')

print(file_path2)
# Out:
# data\read_csv_sample.csv

# %%
# read_csv() 함수로 데이터프레임 변환. 변수 df1에 저장
df1 = pd.read_csv(file_path)
print(df1)
# Out:
#    c0  c1  c2  c3
# 0   0   1   4   7
# 1   1   2   5   8
# 2   2   3   6   9

# %%
# read_csv() 함수로 데이터프레임 변환. 변수 df2에 저장. header=None 옵션은 헤더 표현 안하겠다는 뜻
df2 = pd.read_csv(file_path, header=None)
print(df2)
# Out:
#     0   1   2   3
# 0  c0  c1  c2  c3
# 1   0   1   4   7
# 2   1   2   5   8
# 3   2   3   6   9

# %%
# read_csv() 함수로 데이터프레임 변환. 변수 df3에 저장. index_col=None 옵션
df3 = pd.read_csv(file_path, index_col=None)
print(df3)
# Out:
#    c0  c1  c2  c3
# 0   0   1   4   7
# 1   1   2   5   8
# 2   2   3   6   9

# %%
# read_csv() 함수로 데이터프레임 변환. 변수 df4에 저장. index_col='c0' 옵션
df4 = pd.read_csv(file_path, index_col='c0')
print(df4)
# Out:
#     c1  c2  c3
# c0
# 0    1   4   7
# 1    2   5   8
# 2    3   6   9
